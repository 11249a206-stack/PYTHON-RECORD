# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a206-stack/PYTHON-RECORD/blob/main/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q4="""3. Fibonacci sequence: Defined as a function F as Fn = Fn-1 + Fn-2. Write a Python program which accepts a value for N (w
# print(Q3) # Removed as Q3 is not defined
def fibonacci_sequence(N):
    if N <= 0:
        print("Error: N must be greater than 0.")
        return
    fib_list = []
    a, b = 0, 1
    for _ in range(N):
        fib_list.append(a)
        a, b = b, a + b
    print("Fibonacci sequence up to", N, "terms:", fib_list)
try:
    N = int(input("Enter the number of terms (N > 0): "))
    fibonacci_sequence(N)
except ValueError:
    print("Error: Please enter a valid integer.")
# Out:
# Enter the number of terms (N > 0): 5
# Fibonacci sequence up to 5 terms: [0, 1, 1, 2, 3]
