# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a206-stack/PYTHON-RECORD/blob/main/exp8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q8="7.1. Write a python program to implement insertion sort using lists."
# print(Q71) # This line caused a NameError in the previous execution, so I'm commenting it out.
def insertion_sort(arr):
  for i in range(1, len(arr)):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
      arr[j + 1] = arr[j]
      j -= 1
    arr[j + 1] = key

# Example usage:
nums = [8, 7, 13, 1, -9, 4]
insertion_sort(nums)
print("Insertion sort result:", nums)
# Out:
# Insertion sort result: [-9, 1, 4, 7, 8, 13]
